-- %% [markdown]
-- # [projeto-pf]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [projeto-pf]    Script Date: 29/10/2025 18:03:53 ******/
CREATE DATABASE [projeto-pf]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'projeto-pf', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\projeto-pf.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'projeto-pf_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\projeto-pf_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [projeto-pf] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [projeto-pf].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [projeto-pf] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [projeto-pf] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [projeto-pf] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [projeto-pf] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [projeto-pf] SET ARITHABORT OFF 
GO
ALTER DATABASE [projeto-pf] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [projeto-pf] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [projeto-pf] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [projeto-pf] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [projeto-pf] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [projeto-pf] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [projeto-pf] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [projeto-pf] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [projeto-pf] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [projeto-pf] SET  ENABLE_BROKER 
GO
ALTER DATABASE [projeto-pf] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [projeto-pf] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [projeto-pf] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [projeto-pf] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [projeto-pf] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [projeto-pf] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [projeto-pf] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [projeto-pf] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [projeto-pf] SET  MULTI_USER 
GO
ALTER DATABASE [projeto-pf] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [projeto-pf] SET DB_CHAINING OFF 
GO
ALTER DATABASE [projeto-pf] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [projeto-pf] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [projeto-pf] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [projeto-pf] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [projeto-pf] SET QUERY_STORE = ON
GO
ALTER DATABASE [projeto-pf] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Categorias]

-- %%
USE [projeto-pf]
GO

-- %%
/****** Object:  Table [dbo].[Categorias]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categorias](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descricao] [varchar](50) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cidades]

-- %%
/****** Object:  Table [dbo].[Cidades]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cidades](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](80) NOT NULL,
	[DDD] [nvarchar](3) NOT NULL,
	[IdEstado] [int] NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TipoPessoa] [varchar](10) NOT NULL,
	[NomeRazaoSocial] [varchar](50) NOT NULL,
	[ApelidoNomeFantasia] [varchar](40) NULL,
	[DataNascimentoCriacao] [datetime] NULL,
	[CpfCnpj] [varchar](18) NULL,
	[RgInscricaoEstadual] [varchar](15) NULL,
	[Email] [varchar](100) NOT NULL,
	[Telefone] [varchar](20) NOT NULL,
	[Rua] [varchar](40) NOT NULL,
	[Numero] [varchar](10) NOT NULL,
	[Bairro] [varchar](40) NOT NULL,
	[IdCidade] [int] NOT NULL,
	[Cep] [varchar](10) NULL,
	[Classificacao] [varchar](20) NULL,
	[CondicaoPagamentoId] [int] NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Complemento] [varchar](40) NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Clientes__3214EC07BC2BA1E7] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Compras]

-- %%
/****** Object:  Table [dbo].[Compras]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Compras](
	[DataCriacao] [datetime2](0) NOT NULL,
	[DataAtualizacao] [datetime2](0) NULL,
	[Ativo] [bit] NOT NULL,
	[Modelo] [varchar](2) NOT NULL,
	[Serie] [varchar](3) NOT NULL,
	[NumeroNota] [varchar](6) NOT NULL,
	[DataEmissao] [datetime2](0) NOT NULL,
	[DataEntrega] [datetime2](0) NOT NULL,
	[IdFornecedor] [int] NOT NULL,
	[IdCondicaoPagamento] [int] NOT NULL,
	[ValorFrete] [decimal](18, 2) NULL,
	[ValorSeguro] [decimal](18, 2) NULL,
	[OutrasDespesas] [decimal](18, 2) NULL,
	[ValorTotal] [decimal](18, 2) NOT NULL,
	[MotivoCancelamento] [nvarchar](100) NULL,
	[Observacao] [nvarchar](max) NULL,
 CONSTRAINT [PK_Compras_Natural] PRIMARY KEY CLUSTERED 
(
	[Modelo] ASC,
	[Serie] ASC,
	[NumeroNota] ASC,
	[IdFornecedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_Compras_Modelo_Serie_Nota_Fornecedor] UNIQUE NONCLUSTERED 
(
	[Modelo] ASC,
	[Serie] ASC,
	[NumeroNota] ASC,
	[IdFornecedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CondicaoPagamentoParcelas]

-- %%
/****** Object:  Table [dbo].[CondicaoPagamentoParcelas]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CondicaoPagamentoParcelas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdCondicaoPagamento] [int] NOT NULL,
	[IdFormaPagamento] [int] NOT NULL,
	[NumParcela] [int] NOT NULL,
	[Prazo] [int] NOT NULL,
	[Porcentagem] [decimal](18, 2) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Condicao__3214EC0714F7677A] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CondicaoPagamentos]

-- %%
/****** Object:  Table [dbo].[CondicaoPagamentos]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CondicaoPagamentos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descricao] [varchar](50) NOT NULL,
	[TaxaJuros] [decimal](5, 2) NOT NULL,
	[Multa] [decimal](5, 2) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Desconto] [decimal](18, 2) NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Condicao__3214EC075C33FF8A] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContasAPagar]

-- %%
/****** Object:  Table [dbo].[ContasAPagar]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContasAPagar](
	[DataCriacao] [datetime2](0) NOT NULL,
	[DataAtualizacao] [datetime2](0) NULL,
	[Ativo] [bit] NOT NULL,
	[NumeroParcela] [int] NOT NULL,
	[DataVencimento] [datetime2](0) NOT NULL,
	[ValorParcela] [decimal](18, 2) NOT NULL,
	[IdFormaPagamento] [int] NOT NULL,
	[Modelo] [varchar](2) NOT NULL,
	[Serie] [varchar](3) NOT NULL,
	[NumeroNota] [varchar](6) NOT NULL,
	[IdFornecedor] [int] NOT NULL,
	[DataEmissao] [datetime] NOT NULL,
	[Multa] [decimal](18, 2) NULL,
	[Juros] [decimal](18, 2) NULL,
	[Desconto] [decimal](18, 2) NULL,
	[DataPagamento] [datetime] NULL,
	[ValorFinalParcela] [decimal](10, 2) NULL,
	[Observacao] [nvarchar](200) NULL,
	[Situacao] [nvarchar](20) NULL,
	[MotivoCancelamento] [nvarchar](255) NULL,
 CONSTRAINT [PK_ContasAPagar] PRIMARY KEY CLUSTERED 
(
	[Modelo] ASC,
	[Serie] ASC,
	[NumeroNota] ASC,
	[IdFornecedor] ASC,
	[NumeroParcela] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estados]

-- %%
/****** Object:  Table [dbo].[Estados]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estados](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](80) NOT NULL,
	[UF] [nvarchar](2) NOT NULL,
	[IdPais] [int] NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Estados__3214EC07E1F2604F] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FormaPagamentos]

-- %%
/****** Object:  Table [dbo].[FormaPagamentos]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FormaPagamentos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descricao] [varchar](40) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK_FormaPagamentos] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fornecedores]

-- %%
/****** Object:  Table [dbo].[Fornecedores]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fornecedores](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TipoPessoa] [varchar](10) NOT NULL,
	[NomeRazaoSocial] [varchar](50) NOT NULL,
	[ApelidoNomeFantasia] [varchar](40) NULL,
	[DataNascimentoCriacao] [datetime] NULL,
	[CpfCnpj] [varchar](18) NULL,
	[RgInscricaoEstadual] [varchar](15) NULL,
	[Email] [varchar](100) NOT NULL,
	[Telefone] [varchar](20) NOT NULL,
	[Rua] [varchar](40) NOT NULL,
	[Numero] [varchar](10) NOT NULL,
	[Bairro] [varchar](40) NOT NULL,
	[IdCidade] [int] NOT NULL,
	[Cep] [varchar](10) NULL,
	[Classificacao] [varchar](20) NULL,
	[CondicaoPagamentoId] [int] NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[ValorMinimoPedido] [decimal](18, 2) NULL,
	[Complemento] [varchar](40) NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Forneced__3214EC07B424E11D] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Funcionarios]

-- %%
/****** Object:  Table [dbo].[Funcionarios]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Funcionarios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Matricula] [varchar](20) NOT NULL,
	[NomeRazaoSocial] [varchar](50) NOT NULL,
	[ApelidoNomeFantasia] [varchar](40) NULL,
	[DataNascimentoCriacao] [datetime] NULL,
	[Email] [varchar](100) NOT NULL,
	[Telefone] [varchar](20) NOT NULL,
	[Rua] [varchar](40) NOT NULL,
	[Numero] [varchar](10) NOT NULL,
	[Bairro] [varchar](40) NOT NULL,
	[Cep] [varchar](10) NULL,
	[IdCidade] [int] NOT NULL,
	[CpfCnpj] [varchar](18) NULL,
	[RgInscricaoEstadual] [varchar](15) NULL,
	[Classificacao] [varchar](20) NULL,
	[Cargo] [varchar](20) NOT NULL,
	[Salario] [decimal](10, 2) NOT NULL,
	[DataAdmissao] [date] NOT NULL,
	[Turno] [varchar](20) NOT NULL,
	[CargaHoraria] [varchar](20) NOT NULL,
	[DataDemissao] [date] NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[COMPLEMENTO] [varchar](40) NULL,
	[TipoPessoa] [varchar](20) NULL,
	[Ativo] [bit] NOT NULL,
 CONSTRAINT [PK__Funciona__3214EC07CEB30AE5] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ItensCompra]

-- %%
/****** Object:  Table [dbo].[ItensCompra]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ItensCompra](
	[DataCriacao] [datetime2](0) NOT NULL,
	[DataAtualizacao] [datetime2](0) NULL,
	[Ativo] [bit] NOT NULL,
	[IdProduto] [int] NOT NULL,
	[Quantidade] [decimal](18, 4) NOT NULL,
	[ValorUnitario] [decimal](18, 4) NOT NULL,
	[Total] [decimal](18, 2) NOT NULL,
	[Modelo] [varchar](2) NOT NULL,
	[Serie] [varchar](3) NOT NULL,
	[NumeroNota] [varchar](6) NOT NULL,
	[IdFornecedor] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Marcas]

-- %%
/****** Object:  Table [dbo].[Marcas]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Marcas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descricao] [varchar](50) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paises]

-- %%
/****** Object:  Table [dbo].[Paises]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paises](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](40) NOT NULL,
	[Sigla] [nvarchar](5) NOT NULL,
	[DDI] [nvarchar](5) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProdutoFornecedor]

-- %%
/****** Object:  Table [dbo].[ProdutoFornecedor]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProdutoFornecedor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdProduto] [int] NOT NULL,
	[IdFornecedor] [int] NOT NULL,
	[PrecoUltimaCompra] [decimal](18, 4) NULL,
	[DataUltimaCompra] [date] NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NOT NULL,
	[Ativo] [bit] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_ProdutoFornecedor] UNIQUE NONCLUSTERED 
(
	[IdProduto] ASC,
	[IdFornecedor] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produtos]

-- %%
/****** Object:  Table [dbo].[Produtos]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produtos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [varchar](50) NOT NULL,
	[IdUnidadeMedida] [int] NOT NULL,
	[IdCategoria] [int] NOT NULL,
	[IdMarca] [int] NULL,
	[Estoque] [decimal](10, 2) NOT NULL,
	[PrecoCusto] [decimal](10, 2) NOT NULL,
	[PrecoVenda] [decimal](10, 2) NOT NULL,
	[CustoUltimaCompra] [decimal](10, 2) NULL,
	[Observacao] [text] NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
	[MargemLucro] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UnidadeMedidas]

-- %%
/****** Object:  Table [dbo].[UnidadeMedidas]    Script Date: 29/10/2025 18:03:53 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UnidadeMedidas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descricao] [varchar](50) NOT NULL,
	[DataCriacao] [datetime] NOT NULL,
	[DataAtualizacao] [datetime] NULL,
	[Ativo] [bit] NOT NULL,
	[Sigla] [varchar](3) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Cidades__Ativo__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Cidades] ADD  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__Clientes__DataCr__2645B050]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  CONSTRAINT [DF__Clientes__DataCr__2645B050]  DEFAULT (getdate()) FOR [DataCriacao]
GO

-- %% [markdown]
-- # [DF__Clientes__DataAt__2739D489]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  CONSTRAINT [DF__Clientes__DataAt__2739D489]  DEFAULT (getdate()) FOR [DataAtualizacao]
GO

-- %% [markdown]
-- # [DF__Clientes__Ativo__3493CFA7]

-- %%
ALTER TABLE [dbo].[Clientes] ADD  CONSTRAINT [DF__Clientes__Ativo__3493CFA7]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__CondicaoP__Ativo__3A4CA8FD]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentoParcelas] ADD  CONSTRAINT [DF__CondicaoP__Ativo__3A4CA8FD]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__CondicaoP__TaxaJ__6383C8BA]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__TaxaJ__6383C8BA]  DEFAULT ((0.00)) FOR [TaxaJuros]
GO

-- %% [markdown]
-- # [DF__CondicaoP__Multa__6477ECF3]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__Multa__6477ECF3]  DEFAULT ((0.00)) FOR [Multa]
GO

-- %% [markdown]
-- # [DF__CondicaoP__DataC__656C112C]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__DataC__656C112C]  DEFAULT (getdate()) FOR [DataCriacao]
GO

-- %% [markdown]
-- # [DF__CondicaoP__DataA__66603565]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__DataA__66603565]  DEFAULT (getdate()) FOR [DataAtualizacao]
GO

-- %% [markdown]
-- # [DF__CondicaoP__Desco__30C33EC3]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__Desco__30C33EC3]  DEFAULT ((0)) FOR [Desconto]
GO

-- %% [markdown]
-- # [DF__CondicaoP__Ativo__3587F3E0]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentos] ADD  CONSTRAINT [DF__CondicaoP__Ativo__3587F3E0]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__ContasAPa__Multa__3FD07829]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF__ContasAPa__Multa__3FD07829]  DEFAULT ((0)) FOR [Multa]
GO

-- %% [markdown]
-- # [DF__ContasAPa__Juros__40C49C62]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF__ContasAPa__Juros__40C49C62]  DEFAULT ((0)) FOR [Juros]
GO

-- %% [markdown]
-- # [DF__ContasAPa__Desco__41B8C09B]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF__ContasAPa__Desco__41B8C09B]  DEFAULT ((0)) FOR [Desconto]
GO

-- %% [markdown]
-- # [DF_ContasAPagar_DataPagamento]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF_ContasAPagar_DataPagamento]  DEFAULT (getdate()) FOR [DataPagamento]
GO

-- %% [markdown]
-- # [DF_ContasAPagar_ValorFinal]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF_ContasAPagar_ValorFinal]  DEFAULT ((0)) FOR [ValorFinalParcela]
GO

-- %% [markdown]
-- # [DF__ContasAPa__Obser__6BAEFA67]

-- %%
ALTER TABLE [dbo].[ContasAPagar] ADD  CONSTRAINT [DF__ContasAPa__Obser__6BAEFA67]  DEFAULT ('') FOR [Observacao]
GO

-- %% [markdown]
-- # [DF__Estados__Ativo__367C1819]

-- %%
ALTER TABLE [dbo].[Estados] ADD  CONSTRAINT [DF__Estados__Ativo__367C1819]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__FormaPaga__Ativo__32AB8735]

-- %%
ALTER TABLE [dbo].[FormaPagamentos] ADD  CONSTRAINT [DF__FormaPaga__Ativo__32AB8735]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__Fornecedo__Ativo__37703C52]

-- %%
ALTER TABLE [dbo].[Fornecedores] ADD  CONSTRAINT [DF__Fornecedo__Ativo__37703C52]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__Funcionar__Ativo__3864608B]

-- %%
ALTER TABLE [dbo].[Funcionarios] ADD  CONSTRAINT [DF__Funcionar__Ativo__3864608B]  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__Paises__Ativo__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[Paises] ADD  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__ProdutoFo__DataC__3F115E1A]

-- %%
ALTER TABLE [dbo].[ProdutoFornecedor] ADD  DEFAULT (getdate()) FOR [DataCriacao]
GO

-- %% [markdown]
-- # [DF__ProdutoFo__DataA__40058253]

-- %%
ALTER TABLE [dbo].[ProdutoFornecedor] ADD  DEFAULT (getdate()) FOR [DataAtualizacao]
GO

-- %% [markdown]
-- # [DF__ProdutoFo__Ativo__40F9A68C]

-- %%
ALTER TABLE [dbo].[ProdutoFornecedor] ADD  DEFAULT ((1)) FOR [Ativo]
GO

-- %% [markdown]
-- # [DF__Produtos__Margem__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Produtos] ADD  DEFAULT ((0)) FOR [MargemLucro]
GO

-- %% [markdown]
-- # [DF__UnidadeMe__Sigla__5EBF139D]

-- %%
ALTER TABLE [dbo].[UnidadeMedidas] ADD  DEFAULT ('') FOR [Sigla]
GO

-- %% [markdown]
-- # [FK__Cidades__IdEstad__07C12930]

-- %%
ALTER TABLE [dbo].[Cidades]  WITH CHECK ADD  CONSTRAINT [FK__Cidades__IdEstad__07C12930] FOREIGN KEY([IdEstado])
REFERENCES [dbo].[Estados] ([Id])
GO
ALTER TABLE [dbo].[Cidades] CHECK CONSTRAINT [FK__Cidades__IdEstad__07C12930]
GO

-- %% [markdown]
-- # [FK_Cidade]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH CHECK ADD  CONSTRAINT [FK_Cidade] FOREIGN KEY([IdCidade])
REFERENCES [dbo].[Cidades] ([Id])
GO
ALTER TABLE [dbo].[Clientes] CHECK CONSTRAINT [FK_Cidade]
GO

-- %% [markdown]
-- # [FK_CondicaoPagamentoCliente]

-- %%
ALTER TABLE [dbo].[Clientes]  WITH CHECK ADD  CONSTRAINT [FK_CondicaoPagamentoCliente] FOREIGN KEY([CondicaoPagamentoId])
REFERENCES [dbo].[CondicaoPagamentos] ([Id])
GO
ALTER TABLE [dbo].[Clientes] CHECK CONSTRAINT [FK_CondicaoPagamentoCliente]
GO

-- %% [markdown]
-- # [FK_Compras_Condicao]

-- %%
ALTER TABLE [dbo].[Compras]  WITH CHECK ADD  CONSTRAINT [FK_Compras_Condicao] FOREIGN KEY([IdCondicaoPagamento])
REFERENCES [dbo].[CondicaoPagamentos] ([Id])
GO
ALTER TABLE [dbo].[Compras] CHECK CONSTRAINT [FK_Compras_Condicao]
GO

-- %% [markdown]
-- # [FK_Compras_CondicaoPagamentos]

-- %%
ALTER TABLE [dbo].[Compras]  WITH CHECK ADD  CONSTRAINT [FK_Compras_CondicaoPagamentos] FOREIGN KEY([IdCondicaoPagamento])
REFERENCES [dbo].[CondicaoPagamentos] ([Id])
GO
ALTER TABLE [dbo].[Compras] CHECK CONSTRAINT [FK_Compras_CondicaoPagamentos]
GO

-- %% [markdown]
-- # [FK_Compras_Fornecedor]

-- %%
ALTER TABLE [dbo].[Compras]  WITH CHECK ADD  CONSTRAINT [FK_Compras_Fornecedor] FOREIGN KEY([IdFornecedor])
REFERENCES [dbo].[Fornecedores] ([Id])
GO
ALTER TABLE [dbo].[Compras] CHECK CONSTRAINT [FK_Compras_Fornecedor]
GO

-- %% [markdown]
-- # [FK_Compras_Fornecedores]

-- %%
ALTER TABLE [dbo].[Compras]  WITH CHECK ADD  CONSTRAINT [FK_Compras_Fornecedores] FOREIGN KEY([IdFornecedor])
REFERENCES [dbo].[Fornecedores] ([Id])
GO
ALTER TABLE [dbo].[Compras] CHECK CONSTRAINT [FK_Compras_Fornecedores]
GO

-- %% [markdown]
-- # [FK_CondicaoPagamento]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentoParcelas]  WITH CHECK ADD  CONSTRAINT [FK_CondicaoPagamento] FOREIGN KEY([IdCondicaoPagamento])
REFERENCES [dbo].[CondicaoPagamentos] ([Id])
GO
ALTER TABLE [dbo].[CondicaoPagamentoParcelas] CHECK CONSTRAINT [FK_CondicaoPagamento]
GO

-- %% [markdown]
-- # [FK_FormaPagamento]

-- %%
ALTER TABLE [dbo].[CondicaoPagamentoParcelas]  WITH CHECK ADD  CONSTRAINT [FK_FormaPagamento] FOREIGN KEY([IdFormaPagamento])
REFERENCES [dbo].[FormaPagamentos] ([Id])
GO
ALTER TABLE [dbo].[CondicaoPagamentoParcelas] CHECK CONSTRAINT [FK_FormaPagamento]
GO

-- %% [markdown]
-- # [FK__Estados__IdPais__04E4BC85]

-- %%
ALTER TABLE [dbo].[Estados]  WITH CHECK ADD  CONSTRAINT [FK__Estados__IdPais__04E4BC85] FOREIGN KEY([IdPais])
REFERENCES [dbo].[Paises] ([Id])
GO
ALTER TABLE [dbo].[Estados] CHECK CONSTRAINT [FK__Estados__IdPais__04E4BC85]
GO

-- %% [markdown]
-- # [FK_Fornecedores_Cidades]

-- %%
ALTER TABLE [dbo].[Fornecedores]  WITH CHECK ADD  CONSTRAINT [FK_Fornecedores_Cidades] FOREIGN KEY([IdCidade])
REFERENCES [dbo].[Cidades] ([Id])
GO
ALTER TABLE [dbo].[Fornecedores] CHECK CONSTRAINT [FK_Fornecedores_Cidades]
GO

-- %% [markdown]
-- # [FK_Fornecedores_CondicaoPagamentos]

-- %%
ALTER TABLE [dbo].[Fornecedores]  WITH CHECK ADD  CONSTRAINT [FK_Fornecedores_CondicaoPagamentos] FOREIGN KEY([CondicaoPagamentoId])
REFERENCES [dbo].[CondicaoPagamentos] ([Id])
GO
ALTER TABLE [dbo].[Fornecedores] CHECK CONSTRAINT [FK_Fornecedores_CondicaoPagamentos]
GO

-- %% [markdown]
-- # [FK_Funcionarios_Cidades]

-- %%
ALTER TABLE [dbo].[Funcionarios]  WITH CHECK ADD  CONSTRAINT [FK_Funcionarios_Cidades] FOREIGN KEY([IdCidade])
REFERENCES [dbo].[Cidades] ([Id])
GO
ALTER TABLE [dbo].[Funcionarios] CHECK CONSTRAINT [FK_Funcionarios_Cidades]
GO

-- %% [markdown]
-- # [FK_ItensCompra_Compras_Natural]

-- %%
ALTER TABLE [dbo].[ItensCompra]  WITH CHECK ADD  CONSTRAINT [FK_ItensCompra_Compras_Natural] FOREIGN KEY([Modelo], [Serie], [NumeroNota], [IdFornecedor])
REFERENCES [dbo].[Compras] ([Modelo], [Serie], [NumeroNota], [IdFornecedor])
GO
ALTER TABLE [dbo].[ItensCompra] CHECK CONSTRAINT [FK_ItensCompra_Compras_Natural]
GO

-- %% [markdown]
-- # [FK_ItensCompra_Produto]

-- %%
ALTER TABLE [dbo].[ItensCompra]  WITH CHECK ADD  CONSTRAINT [FK_ItensCompra_Produto] FOREIGN KEY([IdProduto])
REFERENCES [dbo].[Produtos] ([Id])
GO
ALTER TABLE [dbo].[ItensCompra] CHECK CONSTRAINT [FK_ItensCompra_Produto]
GO

-- %% [markdown]
-- # [FK_ItensCompra_Produtos]

-- %%
ALTER TABLE [dbo].[ItensCompra]  WITH CHECK ADD  CONSTRAINT [FK_ItensCompra_Produtos] FOREIGN KEY([IdProduto])
REFERENCES [dbo].[Produtos] ([Id])
GO
ALTER TABLE [dbo].[ItensCompra] CHECK CONSTRAINT [FK_ItensCompra_Produtos]
GO

-- %% [markdown]
-- # [FK_ProdutoFornecedor_Fornecedor]

-- %%
ALTER TABLE [dbo].[ProdutoFornecedor]  WITH CHECK ADD  CONSTRAINT [FK_ProdutoFornecedor_Fornecedor] FOREIGN KEY([IdFornecedor])
REFERENCES [dbo].[Fornecedores] ([Id])
GO
ALTER TABLE [dbo].[ProdutoFornecedor] CHECK CONSTRAINT [FK_ProdutoFornecedor_Fornecedor]
GO

-- %% [markdown]
-- # [FK_ProdutoFornecedor_Produto]

-- %%
ALTER TABLE [dbo].[ProdutoFornecedor]  WITH CHECK ADD  CONSTRAINT [FK_ProdutoFornecedor_Produto] FOREIGN KEY([IdProduto])
REFERENCES [dbo].[Produtos] ([Id])
GO
ALTER TABLE [dbo].[ProdutoFornecedor] CHECK CONSTRAINT [FK_ProdutoFornecedor_Produto]
GO

-- %% [markdown]
-- # [FK_Produtos_Categoria]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK_Produtos_Categoria] FOREIGN KEY([IdCategoria])
REFERENCES [dbo].[Categorias] ([Id])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK_Produtos_Categoria]
GO

-- %% [markdown]
-- # [FK_Produtos_Marca]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK_Produtos_Marca] FOREIGN KEY([IdMarca])
REFERENCES [dbo].[Marcas] ([Id])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK_Produtos_Marca]
GO

-- %% [markdown]
-- # [FK_Produtos_UnidadeMedida]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK_Produtos_UnidadeMedida] FOREIGN KEY([IdUnidadeMedida])
REFERENCES [dbo].[UnidadeMedidas] ([Id])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK_Produtos_UnidadeMedida]
GO

-- %% [markdown]
-- # [projeto-pf]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [projeto-pf] SET  READ_WRITE 
GO
